# %%
library(tsfeatures)
library(imputeTS)
library(forecast)
library(dplyr)

# %%
data=read.csv('industry.csv')

# %%
head(data)
# Out:
#   指标名称 安徽.建筑业.建筑业总产值.累计值 北京.建筑业.建筑业总产值.累计值
# 1 2003-06  246.22                           454.90
# 2 2003-12  641.84                          1269.85
# 3 2004-03  134.25                           202.25
# 4 2004-06  310.73                           589.12
# 5 2004-09  430.53                           965.87
# 6 2004-12  775.44                          1464.54
#   福建.建筑业.建筑业总产值.累计值 甘肃.建筑业.建筑业总产值.累计值
# 1 168.64                           76.39
# 2 495.36                          200.32
# 3  95.66                           23.79
# 4 218.20                           85.53
# 5 369.97                          146.18
# 6 565.62                          206.13
#   广东.建筑业.建筑业总产值.累计值 广西.建筑业.建筑业总产值.累计值
# 1  555.33                         107.02
# 2 1479.84                         290.84
# 3  371.46                          59.06
# 4  796.11                         131.80
# 5 1224.80                         203.56
# 6 1749.56                         333.59
#   贵州.建筑业.建筑业总产值.累计值 海南.建筑业.建筑业总产值.累计值
# 1  82.98                          18.55
# 2 207.34                          23.99
# 3  49.14                           7.24
# 4 105.57                          20.25
# 5 159.78                          28.34
# 6 245.73                          47.07
#   河北.建筑业.建筑业总产值.累计值 ⋯ 上海.建筑业.建筑业总产值.累计值
# 1 267.60                          ⋯  419.34
# 2 730.40                          ⋯ 1055.88
# 3 105.89                          ⋯  255.44
# 4 321.88                          ⋯  594.82
# 5 485.18                          ⋯  895.10
# 6 849.11                          ⋯ 1738.00
#   陕西.建筑业.建筑业总产值.累计值 山西.建筑业.建筑业总产值.累计值
# 1 160.12                          166.41
# 2 422.47                          492.92
# 3  68.21                           69.06
# 4 201.90                          231.07
# 5 324.51                          389.30
# 6 525.01                          749.49
#   四川.建筑业.建筑业总产值.累计值 天津.建筑业.建筑业总产值.累计值
# 1  413.89                         201.25
# 2 1323.67                         498.66
# 3  263.25                          97.02
# 4  460.05                         273.95
# 5  787.98                         439.73
# 6 1366.46                         631.34
#   新疆.建筑业.建筑业总产值.累计值 西藏.建筑业.建筑业总产值.累计值
# 1  93.40                          11.99
# 2 295.57                          11.99
# 3   7.72                             NA
# 4  91.21                           7.89
# 5 201.73                          15.72
# 6 316.74                          20.79
#   云南.建筑业.建筑业总产值.累计值 浙江.建筑业.建筑业总产值.累计值
# 1 143.41                          1128.61
# 2 348.82                          2973.65
# 3  83.67                           612.98
# 4 172.54                          1499.38
# 5 256.95                          2477.91
# 6 419.96                          3966.77
#   重庆.建筑业.建筑业总产值.累计值
# 1 231.93
# 2 563.25
# 3 140.34
# 4 278.66
# 5 426.53
# 6 662.67

# %%
tail(data)
# Out:
#    指标名称 安徽.建筑业.建筑业总产值.累计值 北京.建筑业.建筑业总产值.累计值
# 75 2022-03   1949.11                         2380.64
# 76 2022-06   5003.97                         6402.69
# 77 2022-09   7890.26                        10013.23
# 78 2022-12  11702.63                        13866.11
# 79 2023-03   2127.69                         2542.96
# 80 2023-06   5391.32                         6768.27
#    福建.建筑业.建筑业总产值.累计值 甘肃.建筑业.建筑业总产值.累计值
# 75  3111.95                         285.70
# 76  7287.85                         997.97
# 77 11547.29                        1668.91
# 78 17129.46                        2477.68
# 79  3195.95                         316.66
# 80  7329.55                        1102.73
#    广东.建筑业.建筑业总产值.累计值 广西.建筑业.建筑业总产值.累计值
# 75  4173.43                        1296.43
# 76  9628.96                        3088.03
# 77 15196.21                        4719.36
# 78 22956.50                        7275.76
# 79  4664.76                        1406.96
# 80 10586.19                        2826.37
#    贵州.建筑业.建筑业总产值.累计值 海南.建筑业.建筑业总产值.累计值
# 75  930.52                          84.99
# 76 2173.44                         178.47
# 77 3154.33                         294.84
# 78 4820.24                         467.21
# 79 1005.65                          89.66
# 80 1724.47                         191.14
#    河北.建筑业.建筑业总产值.累计值 ⋯ 上海.建筑业.建筑业总产值.累计值
# 75  981.81                         ⋯ 1721.93
# 76 2898.36                         ⋯ 3661.00
# 77 4789.99                         ⋯ 6231.17
# 78 6951.34                         ⋯ 9273.90
# 79 1058.79                         ⋯ 1883.83
# 80 3102.42                         ⋯ 4336.17
#    陕西.建筑业.建筑业总产值.累计值 山西.建筑业.建筑业总产值.累计值
# 75  1570.19                         723.94
# 76  4127.81                        2263.17
# 77  6649.32                        4082.43
# 78 10067.87                        6145.48
# 79  1734.92                         790.88
# 80  4371.31                        2393.40
#    四川.建筑业.建筑业总产值.累计值 天津.建筑业.建筑业总产值.累计值
# 75  3412.52                         826.79
# 76  8080.61                        2108.03
# 77 12749.89                        3436.38
# 78 18675.22                        4751.30
# 79  2855.04                         918.32
# 80  7344.82                        2274.34
#    新疆.建筑业.建筑业总产值.累计值 西藏.建筑业.建筑业总产值.累计值
# 75  178.62                          46.63
# 76 1116.03                          86.70
# 77 2197.30                         111.36
# 78 3101.50                         203.79
# 79  202.77                          39.82
# 80 1212.60                          86.28
#    云南.建筑业.建筑业总产值.累计值 浙江.建筑业.建筑业总产值.累计值
# 75 1377.52                          4898.64
# 76 3214.62                         10866.64
# 77 5045.28                         16408.36
# 78 8168.65                         23861.07
# 79 1400.63                          5199.86
# 80 3154.80                         11375.78
#    重庆.建筑业.建筑业总产值.累计值
# 75  2120.09
# 76  4931.70
# 77  7488.88
# 78 10369.40
# 79  2279.40
# 80  4488.52

# %%
data=data[3:80,c(2:dim(data)[2])]

# %%
data_sum_change <-function(data)
{    
data1=matrix(0,dim(data)[1],31)
for(i in 1:dim(data)[1])
    {
    if(i%%4==1) data1[i,]=as.matrix(data[i,])
    if(i%%4!=1) data1[i,]=as.matrix(data[i,]-data[(i-1),])   
}
return(data1)
}
data=data_sum_change(data)

# %%
dim(data)
# Out:
# [1] 78 31

# %%
which_baddata=function(data){
baddata=c()
for(i in 1:dim(data)[2])
{loc=min(which(is.na(data[,i])==FALSE))-1
if((dim(data)[1]-loc)<40)
    {
    baddata=append(baddata,i)
}
else if(sum(is.na(data[loc:dim(data)[1],i])==TRUE)>10)
 {
     baddata=append(baddata,i)
 }
else if(sum(is.na(data[(dim(data)[1]-11):dim(data)[1],i])==TRUE)>3)
 {
     baddata=append(baddata,i)
 }
}
baddata=unique(baddata)
return(baddata)}

# %%
baddata=which_baddata(data)

# %%
baddata
# Out:
# NULL

# %%
#data=data[,-1*baddata]

# %%
#dim(data)

# %%
freq=4
ll=dim(data)[2]
hh=8
start=c(2004,1)
m=5
n=4

# %%
process_data <- function(data, start, freq, hh, ll) {
  data_ts <- list()
  data_tstrain <- list()
  data_features <- NULL
  
  for (i in 1:ll) {
    # 寻找第一个非NA值的位置
    loc <- min(which(is.na(data[, i]) == FALSE)) - 1
    zc <- loc %/% freq
    yu <- loc %% freq
    
    # 提取子序列
    x <- data[(loc + 1):dim(data)[1], i]
    
    # 检测并处理NA值
    r <- which(is.na(x) == TRUE)
    if (length(r) != 0) {
      x <- na_kalman(x) # 假设na_kalman是一个处理NA值的函数
    }
    
    # 创建时间序列对象
    da <- ts(x[1:(length(x) - hh)], start = c(start[1] + zc, start[2] + yu), frequency = freq)
    da1 <- ts(x, start = c(start[1] + zc, start[2] + yu), frequency = freq)
    
    # 保存时间序列对象
    data_ts[[i]] <- da1
    data_tstrain[[i]] <- da
    
    # 提取时间序列特征
    f <- tsfeatures(da)
    if (is.null(data_features)) {
      data_features <- f
    } else {
      data_features <- rbind(data_features, f)
    }
  }
  
  # 函数返回一个列表，包含处理后的时间序列和特征
  list(time_series = data_ts, time_series_train = data_tstrain, features = data_features)
}

# %%
processed_data <- process_data(data, start = start, freq, hh, ll)

# %%
data_ts=processed_data$time_series
data_tstrain=processed_data$time_series_train
data_features=processed_data$features

# %%
head(data_features)
# Out:
#   frequency nperiods seasonal_period trend     spike        linearity
# 1 4         1        4               0.9879529 2.698983e-07 7.603229
# 2 4         1        4               0.9921063 2.597026e-08 7.321174
# 3 4         1        4               0.9940831 1.004223e-07 7.665862
# 4 4         1        4               0.9753742 4.189298e-07 6.638517
# 5 4         1        4               0.9785069 9.241331e-07 7.317223
# 6 4         1        4               0.9891427 1.696863e-07 7.385268
#   curvature  e_acf1     e_acf10   seasonal_strength peak trough entropy
# 1  0.9967596 -0.5381871 0.7126845 0.9259690         4    1      0.4416217
# 2  0.5643619 -0.3498429 0.5740582 0.9695832         4    1      0.4542133
# 3  1.8333139 -0.3526294 0.3779629 0.9465564         4    1      0.3803565
# 4 -0.5897550 -0.4842341 0.5175419 0.9404914         4    1      0.4102417
# 5  2.1530503 -0.4822423 0.6266252 0.8748649         4    1      0.4699761
# 6  1.9595493 -0.5438870 0.6199214 0.9400124         4    1      0.4257430
#   x_acf1    x_acf10  diff1_acf1 diff1_acf10 diff2_acf1 diff2_acf10 seas_acf1
# 1 0.7327696 4.289124 -0.6960024 3.184751    -0.7866623 4.081275    0.8160953
# 2 0.6335998 3.656576 -0.6609949 3.627113    -0.7691548 4.910366    0.8304387
# 3 0.8114638 4.796813 -0.6401912 3.030209    -0.7553713 4.114516    0.8232441
# 4 0.5371915 3.155137 -0.5934951 2.713180    -0.7157153 3.752906    0.8558161
# 5 0.7353441 3.720627 -0.6221071 2.288217    -0.7421370 3.109275    0.7714004
# 6 0.7144684 4.136957 -0.7255195 3.467526    -0.8169358 4.433018    0.8148899

# %%
long=matrix(0,ll,1)
for( i in 1:ll)
    {
    long[i,1]=length(data_tstrain[[i]])
}

# %%
data_features=cbind(data_features,long)

# %%
head(data_features)
# Out:
#   frequency nperiods seasonal_period trend     spike        linearity
# 1 4         1        4               0.9879529 2.698983e-07 7.603229
# 2 4         1        4               0.9921063 2.597026e-08 7.321174
# 3 4         1        4               0.9940831 1.004223e-07 7.665862
# 4 4         1        4               0.9753742 4.189298e-07 6.638517
# 5 4         1        4               0.9785069 9.241331e-07 7.317223
# 6 4         1        4               0.9891427 1.696863e-07 7.385268
#   curvature  e_acf1     e_acf10   seasonal_strength ⋯ trough entropy
# 1  0.9967596 -0.5381871 0.7126845 0.9259690         ⋯ 1      0.4416217
# 2  0.5643619 -0.3498429 0.5740582 0.9695832         ⋯ 1      0.4542133
# 3  1.8333139 -0.3526294 0.3779629 0.9465564         ⋯ 1      0.3803565
# 4 -0.5897550 -0.4842341 0.5175419 0.9404914         ⋯ 1      0.4102417
# 5  2.1530503 -0.4822423 0.6266252 0.8748649         ⋯ 1      0.4699761
# 6  1.9595493 -0.5438870 0.6199214 0.9400124         ⋯ 1      0.4257430
#   x_acf1    x_acf10  diff1_acf1 diff1_acf10 diff2_acf1 diff2_acf10 seas_acf1
# 1 0.7327696 4.289124 -0.6960024 3.184751    -0.7866623 4.081275    0.8160953
# 2 0.6335998 3.656576 -0.6609949 3.627113    -0.7691548 4.910366    0.8304387
# 3 0.8114638 4.796813 -0.6401912 3.030209    -0.7553713 4.114516    0.8232441
# 4 0.5371915 3.155137 -0.5934951 2.713180    -0.7157153 3.752906    0.8558161
# 5 0.7353441 3.720627 -0.6221071 2.288217    -0.7421370 3.109275    0.7714004
# 6 0.7144684 4.136957 -0.7255195 3.467526    -0.8169358 4.433018    0.8148899
#   long
# 1 70
# 2 70
# 3 70
# 4 70
# 5 70
# 6 70

# %%
f1=function(x){
    if( x%%1>=0.5)
        {
        return(as.integer(x)+1)
    }
    else{return(as.integer(x))}
}

# %%
forecast_and_evaluate <- function(data_ts, data_tstrain, m,n,hh, ll) {
  predets <- array(0, dim = c(ll, m, n, 6))
  predhets <- array(0, dim = c(ll, m, n, hh))
  predthetaf <- array(0, dim = c(ll, m, n, 6))
  predhthetaf <- array(0, dim = c(ll, m, n, hh))
  predarima <- array(0, dim = c(ll, m, n, 6))
  predharima <- array(0, dim = c(ll, m, n, hh))
  prednnetar <- array(0, dim = c(ll, m, n, 6))
  predhnnetar <- array(0, dim = c(ll, m, n, hh))
  yreal <- list()
  
  for (k in 1:ll) {
    y <- data_tstrain[[k]]
    yall <- data_ts[[k]]
    y_pred <- ts(yall[(length(yall) - hh + 1):length(yall)], end = end(yall), frequency = frequency(yall))
    y_l=length(y)
    loc = 1:length(y)
    loc_m = as.integer(loc*m/length(y))
    filt_d = data.frame(y,loc_m)
    filt_0=filter(filt_d ,loc_m==0)
    m_l=count(filt_0)
    n_l=m_l/n
    m_l=as.integer(m_l)
    n_l=as.numeric(n_l)
    
    yreal[[k]] <- y_pred
    
    for (i in 0:(m - 1)) {
      for (j in 0:(n-1)) {
        Y <- ts(y[round((i*m_l+j*n_l)+1):y_l], end = end(y), frequency = frequency(yall))
        M <- ets(Y)
        pd <- forecast(M, h = hh)
        predhets[k, (i + 1), (j + 1), ] <- pd$mean
        predets[k, (i + 1), (j + 1), ] <- accuracy(pd, y_pred)[2, 1:6]
        
        M <- thetaf(Y, h = hh)
        pd <- forecast(M, h = hh)
        predhthetaf[k, (i + 1), (j + 1), ] <- pd$mean
        predthetaf[k, (i + 1), (j + 1), ] <- accuracy(pd, y_pred)[2, 1:6]
          
        M <- auto.arima(Y)
        pd <- forecast(M, h = hh)
        predharima[k, (i + 1), (j + 1), ] <- pd$mean
        predarima[k, (i + 1), (j + 1), ] <- accuracy(pd, y_pred)[2, 1:6]
          
        M <- nnetar(Y, h = hh)
        pd <- forecast(M, h = hh)
        predhnnetar[k, (i + 1), (j + 1), ] <- pd$mean
        prednnetar[k, (i + 1), (j + 1), ] <- accuracy(pd, y_pred)[2, 1:6]
        
      }
    }
  }
  
  list(
    pred_ets = list(predhets = predhets, predets = predets),
    pred_thetaf = list(predhthetaf = predhthetaf, predthetaf = predthetaf),
    pred_arima = list(predharima = predharima, predarima = predarima),
    pred_nnetar = list(predhnnetar = predhnnetar, prednnetar = prednnetar),
    y_real = yreal
  )
}

# %%
forecast_list=forecast_and_evaluate(data_ts, data_tstrain, m,n,hh, ll)

# %%
predhets=forecast_list$pred_ets$predhets
predets=forecast_list$pred_ets$predets
predhthetaf=forecast_list$pred_thetaf$predhthetaf
predthetaf=forecast_list$pred_thetaf$predthetaf

predharima=forecast_list$pred_arima$predharima
predarima=forecast_list$pred_arima$predarima
predhnnetar=forecast_list$pred_nnetar$predhnnetar
prednnetar=forecast_list$pred_nnetar$prednnetar

y_real=forecast_list$y_real

# %%
length5=matrix(0,ll,m)
for(k in 1:ll)
{
y = data_tstrain[[k]]
y_l=length(y)
loc = 1:length(y)
loc_m = as.integer(loc*m/length(y))
filt_d = data.frame(y,loc_m)
filt_0=filter(filt_d ,loc_m==0)
m_l=count(filt_0)
m_l=as.integer(m_l)
length5[k,]=c(0,1*m_l,2*m_l,3*m_l,4*m_l)
    }

# %%
library("xgboost")
library("Matrix")
library('Ckmeans.1d.dp')
library(lightgbm)
# Out:
# Attaching package: ‘xgboost’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     slice
#
#
#
# Attaching package: ‘lightgbm’
#
#
# The following object is masked from ‘package:xgboost’:
#
#     slice
#
#
# The following object is masked from ‘package:dplyr’:
#
#     slice

# %%
meanunique=function(x)
    {
    mean(unique(x))
}

# %%
whichmin<-function(x){
    minx=min(x[x>0])
    loc=which(x==minx)[1]-1
    loc
}

# %%
realbest_construct<-function(MASE)
    {
realbestmean=matrix(0,dim(MASE)[1],1)
for(i in seq(1,dim(MASE)[1]))
    {
    count=MASE[i,,]
    line=apply(count,1,meanunique)
    if (max(line,na.rm = TRUE)==0){
        realbestmean[i,]=0
        }
    else
        {
        line[is.na(line)]=100 
        realbestmean[i,]= whichmin(line)
    }
    }
    return(realbestmean)
    }

# %%
MASEets=predets[,,,6]
MASEthetaf=predthetaf[,,,6]
MASEarima=predarima[,,,6]
MASEnnetar=prednnetar[,,,6]

realbestmeanets=realbest_construct(MASEets)
realbestmeanthetaf=realbest_construct(MASEthetaf)
realbestmeanarima=realbest_construct(MASEarima)
realbestmeannnetar=realbest_construct(MASEnnetar)

# %%
set.seed(50)
index = sample(2,nrow(data_features),replace = TRUE,prob=c(0.7,0.3))
train_data=data_features[index==1,]
test_data=data_features[index==2,]
train_label_ets=realbestmeanets[index==1,]
test_label_ets=realbestmeanets[index==2,]
train_label_thetaf=realbestmeanthetaf[index==1,]
test_label_thetaf=realbestmeanthetaf[index==2,]
               
train_label_arima=realbestmeanarima[index==1,]
test_label_arima=realbestmeanarima[index==2,]
train_label_nnetar=realbestmeannnetar[index==1,]
test_label_nnetar=realbestmeannnetar[index==2,]

# %% [markdown]
# ## 模型训练

# %%
train_models<-function(train_data,train_label)
{
    dtrain_reg <- xgb.DMatrix(data = as.matrix(train_data),label = as.matrix(train_label)) 
    dtrain_cl<- xgb.DMatrix(data = as.matrix(train_data),label = as.matrix(as.factor(train_label)))
    xgbreg  <- xgboost(data = dtrain_reg, nround=100)
    xgbcls  <- xgboost(data = dtrain_cl, nround=100, objective='multi:softmax',num_class=5)
    dtrain_reg <- lgb.Dataset(data = as.matrix(train_data),label = as.matrix(train_label))
    dtrain_cl <- lgb.Dataset(data = as.matrix(train_data),label = as.matrix(as.factor(train_label)))
    # 定义参数列表
    params_reg <- list(
      objective = "regression",
      metric = "rmse"
    )
    lgbreg  <- lgb.train(data = dtrain_reg,nrounds = 100,params = params_reg)
    # 定义参数列表
    params_cl <- list(
      objective = 'multiclass',
      num_class = 5,
      num_iterations = 100  # 使用 num_iterations 代替 nrounds
    )
    # 使用参数列表进行训练
    lgbcls <- lgb.train(data = dtrain_cl,params = params_cl)
    return(list(xgbreg =xgbreg, xgbcls = xgbcls,lgbreg=lgbreg,lgbcls=lgbcls))
}

# %%
models_ets=train_models(train_data,train_label_ets)
etsxgbreg=models_ets$xgbreg
etsxgbcls=models_ets$xgbcls
etslgbreg=models_ets$lgbreg
etslgbcls=models_ets$lgbcls
# Out:
# [1]	train-rmse:1.601086
# [2]	train-rmse:1.210856
# [3]	train-rmse:0.943763
# [4]	train-rmse:0.727310
# [5]	train-rmse:0.564736
# [6]	train-rmse:0.444417
# [7]	train-rmse:0.356236
# [8]	train-rmse:0.286261
# [9]	train-rmse:0.232264
# [10]	train-rmse:0.187967
# [11]	train-rmse:0.153521
# [12]	train-rmse:0.125913
# [13]	train-rmse:0.103147
# [14]	train-rmse:0.084883
# [15]	train-rmse:0.070355
# [16]	train-rmse:0.058463
# [17]	train-rmse:0.048706
# [18]	train-rmse:0.040647
# [19]	train-rmse:0.034054
# [20]	train-rmse:0.028552
# [21]	train-rmse:0.024071
# [22]	train-rmse:0.020303
# [23]	train-rmse:0.017196
# [24]	train-rmse:0.014575
# [25]	train-rmse:0.012373
# [26]	train-rmse:0.010507
# [27]	train-rmse:0.008928
# [28]	train-rmse:0.007587
# [29]	train-rmse:0.006451
# [30]	train-rmse:0.005484
# [31]	train-rmse:0.004673
# [32]	train-rmse:0.003978
# [33]	train-rmse:0.003387
# [34]	train-rmse:0.002890
# [35]	train-rmse:0.002472
# [36]	train-rmse:0.002105
# [37]	train-rmse:0.001820
# [38]	train-rmse:0.001568
# [39]	train-rmse:0.001374
# [40]	train-rmse:0.001165
# [41]	train-rmse:0.001003
# [42]	train-rmse:0.000887
# [43]	train-rmse:0.000801
# [44]	train-rmse:0.000733
# [45]	train-rmse:0.000676
# [46]	train-rmse:0.000643
# [47]	train-rmse:0.000614
# [48]	train-rmse:0.000592
# [49]	train-rmse:0.000591
# [50]	train-rmse:0.000590
# [51]	train-rmse:0.000590
# [52]	train-rmse:0.000590
# [53]	train-rmse:0.000590
# [54]	train-rmse:0.000589
# [55]	train-rmse:0.000589
# [56]	train-rmse:0.000589
# [57]	train-rmse:0.000589
# [58]	train-rmse:0.000589
# [59]	train-rmse:0.000589
# [60]	train-rmse:0.000589
# [61]	train-rmse:0.000589
# [62]	train-rmse:0.000589
# [63]	train-rmse:0.000589
# [64]	train-rmse:0.000589
# [65]	train-rmse:0.000589
# [66]	train-rmse:0.000589
# [67]	train-rmse:0.000589
# [68]	train-rmse:0.000589
# [69]	train-rmse:0.000589
# [70]	train-rmse:0.000589
# [71]	train-rmse:0.000589
# [72]	train-rmse:0.000589
# [73]	train-rmse:0.000589
# [74]	train-rmse:0.000589
# [75]	train-rmse:0.000589
# [76]	train-rmse:0.000589
# [77]	train-rmse:0.000589
# [78]	train-rmse:0.000589
# [79]	train-rmse:0.000589
# [80]	train-rmse:0.000589
# [81]	train-rmse:0.000589
# [82]	train-rmse:0.000589
# [83]	train-rmse:0.000589
# [84]	train-rmse:0.000589
# [85]	train-rmse:0.000589
# [86]	train-rmse:0.000589
# [87]	train-rmse:0.000589
# [88]	train-rmse:0.000589
# [89]	train-rmse:0.000589
# [90]	train-rmse:0.000589
# [91]	train-rmse:0.000589
# [92]	train-rmse:0.000589
# [93]	train-rmse:0.000589
# [94]	train-rmse:0.000589
# [95]	train-rmse:0.000589
# [96]	train-rmse:0.000589
# [97]	train-rmse:0.000589
# [98]	train-rmse:0.000589
# [99]	train-rmse:0.000589
# [100]	train-rmse:0.000589
# [1]	train-mlogloss:1.299026
# [2]	train-mlogloss:1.058000
# [3]	train-mlogloss:0.861817
# [4]	train-mlogloss:0.728596
# [5]	train-mlogloss:0.622339
# [6]	train-mlogloss:0.531931
# [7]	train-mlogloss:0.463561
# [8]	train-mlogloss:0.407306
# [9]	train-mlogloss:0.358772
# [10]	train-mlogloss:0.320235
# [11]	train-mlogloss:0.287956
# [12]	train-mlogloss:0.262791
# [13]	train-mlogloss:0.238732
# [14]	train-mlogloss:0.218127
# [15]	train-mlogloss:0.204354
# [16]	train-mlogloss:0.193220
# [17]	train-mlogloss:0.181437
# [18]	train-mlogloss:0.172651
# [19]	train-mlogloss:0.166987
# [20]	train-mlogloss:0.159601
# [21]	train-mlogloss:0.154479
# [22]	train-mlogloss:0.150465
# [23]	train-mlogloss:0.146911
# [24]	train-mlogloss:0.143379
# [25]	train-mlogloss:0.140178
# [26]	train-mlogloss:0.137145
# [27]	train-mlogloss:0.134350
# [28]	train-mlogloss:0.131634
# [29]	train-mlogloss:0.129128
# [30]	train-mlogloss:0.126747
# [31]	train-mlogloss:0.124542
# [32]	train-mlogloss:0.122469
# [33]	train-mlogloss:0.120930
# [34]	train-mlogloss:0.119334
# [35]	train-mlogloss:0.117801
# [36]	train-mlogloss:0.116312
# [37]	train-mlogloss:0.114952
# [38]	train-mlogloss:0.113574
# [39]	train-mlogloss:0.112315
# [40]	train-mlogloss:0.111035
# [41]	train-mlogloss:0.109825
# [42]	train-mlogloss:0.108659
# [43]	train-mlogloss:0.107543
# [44]	train-mlogloss:0.106417
# [45]	train-mlogloss:0.105380
# [46]	train-mlogloss:0.104313
# [47]	train-mlogloss:0.103330
# [48]	train-mlogloss:0.102387
# [49]	train-mlogloss:0.101489
# [50]	train-mlogloss:0.100667
# [51]	train-mlogloss:0.099913
# [52]	train-mlogloss:0.099212
# [53]	train-mlogloss:0.098613
# [54]	train-mlogloss:0.098039
# [55]	train-mlogloss:0.097506
# [56]	train-mlogloss:0.097032
# [57]	train-mlogloss:0.096607
# [58]	train-mlogloss:0.096216
# [59]	train-mlogloss:0.095844
# [60]	train-mlogloss:0.095496
# [61]	train-mlogloss:0.095167
# [62]	train-mlogloss:0.094854
# [63]	train-mlogloss:0.094632
# [64]	train-mlogloss:0.094415
# [65]	train-mlogloss:0.094196
# [66]	train-mlogloss:0.093986
# [67]	train-mlogloss:0.093785
# [68]	train-mlogloss:0.093588
# [69]	train-mlogloss:0.093398
# [70]	train-mlogloss:0.093210
# [71]	train-mlogloss:0.093036
# [72]	train-mlogloss:0.092864
# [73]	train-mlogloss:0.092705
# [74]	train-mlogloss:0.092547
# [75]	train-mlogloss:0.092401
# [76]	train-mlogloss:0.092267
# [77]	train-mlogloss:0.092143
# [78]	train-mlogloss:0.092029
# [79]	train-mlogloss:0.091922
# [80]	train-mlogloss:0.091854
# [81]	train-mlogloss:0.091787
# [82]	train-mlogloss:0.091721
# [83]	train-mlogloss:0.091656
# [84]	train-mlogloss:0.091592
# [85]	train-mlogloss:0.091529
# [86]	train-mlogloss:0.091467
# [87]	train-mlogloss:0.091405
# [88]	train-mlogloss:0.091344
# [89]	train-mlogloss:0.091284
# [90]	train-mlogloss:0.091225
# [91]	train-mlogloss:0.091167
# [92]	train-mlogloss:0.091109
# [93]	train-mlogloss:0.091052
# [94]	train-mlogloss:0.090995
# [95]	train-mlogloss:0.090939
# [96]	train-mlogloss:0.090884
# [97]	train-mlogloss:0.090830
# [98]	train-mlogloss:0.090776
# [99]	train-mlogloss:0.090723
# [100]	train-mlogloss:0.090670
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 26, number of used features: 0
# [LightGBM] [Info] Start training from score 2.423077
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 26, number of used features: 0
# [LightGBM] [Info] Start training from score -34.538776
# [LightGBM] [Info] Start training from score -1.648659
# [LightGBM] [Info] Start training from score -1.178655
# [LightGBM] [Info] Start training from score -0.955511
# [LightGBM] [Info] Start training from score -2.159484
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements

# %%
models_thetaf=train_models(train_data,train_label_thetaf)
thetafxgbreg=models_thetaf$xgbreg
thetafxgbcls=models_thetaf$xgbcls
thetaflgbreg=models_thetaf$lgbreg
thetaflgbcls=models_thetaf$lgbcls
# Out:
# [1]	train-rmse:1.753665
# [2]	train-rmse:1.300195
# [3]	train-rmse:0.992610
# [4]	train-rmse:0.755644
# [5]	train-rmse:0.580148
# [6]	train-rmse:0.449388
# [7]	train-rmse:0.345934
# [8]	train-rmse:0.271916
# [9]	train-rmse:0.215436
# [10]	train-rmse:0.172576
# [11]	train-rmse:0.139697
# [12]	train-rmse:0.113438
# [13]	train-rmse:0.088923
# [14]	train-rmse:0.072858
# [15]	train-rmse:0.059934
# [16]	train-rmse:0.049470
# [17]	train-rmse:0.040945
# [18]	train-rmse:0.034015
# [19]	train-rmse:0.028362
# [20]	train-rmse:0.023678
# [21]	train-rmse:0.019816
# [22]	train-rmse:0.016619
# [23]	train-rmse:0.013971
# [24]	train-rmse:0.011653
# [25]	train-rmse:0.009753
# [26]	train-rmse:0.008214
# [27]	train-rmse:0.006922
# [28]	train-rmse:0.005850
# [29]	train-rmse:0.004915
# [30]	train-rmse:0.004150
# [31]	train-rmse:0.003515
# [32]	train-rmse:0.002982
# [33]	train-rmse:0.002525
# [34]	train-rmse:0.002146
# [35]	train-rmse:0.001828
# [36]	train-rmse:0.001559
# [37]	train-rmse:0.001335
# [38]	train-rmse:0.001140
# [39]	train-rmse:0.001015
# [40]	train-rmse:0.000914
# [41]	train-rmse:0.000833
# [42]	train-rmse:0.000770
# [43]	train-rmse:0.000652
# [44]	train-rmse:0.000609
# [45]	train-rmse:0.000576
# [46]	train-rmse:0.000529
# [47]	train-rmse:0.000487
# [48]	train-rmse:0.000487
# [49]	train-rmse:0.000486
# [50]	train-rmse:0.000486
# [51]	train-rmse:0.000486
# [52]	train-rmse:0.000486
# [53]	train-rmse:0.000486
# [54]	train-rmse:0.000486
# [55]	train-rmse:0.000486
# [56]	train-rmse:0.000486
# [57]	train-rmse:0.000486
# [58]	train-rmse:0.000486
# [59]	train-rmse:0.000486
# [60]	train-rmse:0.000486
# [61]	train-rmse:0.000486
# [62]	train-rmse:0.000486
# [63]	train-rmse:0.000486
# [64]	train-rmse:0.000486
# [65]	train-rmse:0.000486
# [66]	train-rmse:0.000486
# [67]	train-rmse:0.000486
# [68]	train-rmse:0.000486
# [69]	train-rmse:0.000486
# [70]	train-rmse:0.000486
# [71]	train-rmse:0.000486
# [72]	train-rmse:0.000486
# [73]	train-rmse:0.000486
# [74]	train-rmse:0.000486
# [75]	train-rmse:0.000486
# [76]	train-rmse:0.000486
# [77]	train-rmse:0.000486
# [78]	train-rmse:0.000486
# [79]	train-rmse:0.000486
# [80]	train-rmse:0.000486
# [81]	train-rmse:0.000486
# [82]	train-rmse:0.000486
# [83]	train-rmse:0.000486
# [84]	train-rmse:0.000486
# [85]	train-rmse:0.000486
# [86]	train-rmse:0.000486
# [87]	train-rmse:0.000486
# [88]	train-rmse:0.000486
# [89]	train-rmse:0.000486
# [90]	train-rmse:0.000486
# [91]	train-rmse:0.000486
# [92]	train-rmse:0.000486
# [93]	train-rmse:0.000486
# [94]	train-rmse:0.000486
# [95]	train-rmse:0.000486
# [96]	train-rmse:0.000486
# [97]	train-rmse:0.000486
# [98]	train-rmse:0.000486
# [99]	train-rmse:0.000486
# [100]	train-rmse:0.000486
# [1]	train-mlogloss:1.246238
# [2]	train-mlogloss:0.997316
# [3]	train-mlogloss:0.780112
# [4]	train-mlogloss:0.623515
# [5]	train-mlogloss:0.522966
# [6]	train-mlogloss:0.432001
# [7]	train-mlogloss:0.363697
# [8]	train-mlogloss:0.318798
# [9]	train-mlogloss:0.274962
# [10]	train-mlogloss:0.241960
# [11]	train-mlogloss:0.215554
# [12]	train-mlogloss:0.197744
# [13]	train-mlogloss:0.181378
# [14]	train-mlogloss:0.167798
# [15]	train-mlogloss:0.160088
# [16]	train-mlogloss:0.151393
# [17]	train-mlogloss:0.143951
# [18]	train-mlogloss:0.140703
# [19]	train-mlogloss:0.137028
# [20]	train-mlogloss:0.134332
# [21]	train-mlogloss:0.132266
# [22]	train-mlogloss:0.130407
# [23]	train-mlogloss:0.128727
# [24]	train-mlogloss:0.127359
# [25]	train-mlogloss:0.125994
# [26]	train-mlogloss:0.124787
# [27]	train-mlogloss:0.123627
# [28]	train-mlogloss:0.122577
# [29]	train-mlogloss:0.121591
# [30]	train-mlogloss:0.120599
# [31]	train-mlogloss:0.119734
# [32]	train-mlogloss:0.118890
# [33]	train-mlogloss:0.118142
# [34]	train-mlogloss:0.117445
# [35]	train-mlogloss:0.116753
# [36]	train-mlogloss:0.116115
# [37]	train-mlogloss:0.115524
# [38]	train-mlogloss:0.114964
# [39]	train-mlogloss:0.114410
# [40]	train-mlogloss:0.113872
# [41]	train-mlogloss:0.113380
# [42]	train-mlogloss:0.112879
# [43]	train-mlogloss:0.112396
# [44]	train-mlogloss:0.111934
# [45]	train-mlogloss:0.111489
# [46]	train-mlogloss:0.111062
# [47]	train-mlogloss:0.110645
# [48]	train-mlogloss:0.110255
# [49]	train-mlogloss:0.109850
# [50]	train-mlogloss:0.109485
# [51]	train-mlogloss:0.109118
# [52]	train-mlogloss:0.108738
# [53]	train-mlogloss:0.108376
# [54]	train-mlogloss:0.108022
# [55]	train-mlogloss:0.107670
# [56]	train-mlogloss:0.107337
# [57]	train-mlogloss:0.106988
# [58]	train-mlogloss:0.106644
# [59]	train-mlogloss:0.106321
# [60]	train-mlogloss:0.105996
# [61]	train-mlogloss:0.105674
# [62]	train-mlogloss:0.105366
# [63]	train-mlogloss:0.105041
# [64]	train-mlogloss:0.104728
# [65]	train-mlogloss:0.104429
# [66]	train-mlogloss:0.104143
# [67]	train-mlogloss:0.103856
# [68]	train-mlogloss:0.103569
# [69]	train-mlogloss:0.103298
# [70]	train-mlogloss:0.103029
# [71]	train-mlogloss:0.102763
# [72]	train-mlogloss:0.102509
# [73]	train-mlogloss:0.102247
# [74]	train-mlogloss:0.101991
# [75]	train-mlogloss:0.101735
# [76]	train-mlogloss:0.101498
# [77]	train-mlogloss:0.101258
# [78]	train-mlogloss:0.101037
# [79]	train-mlogloss:0.100832
# [80]	train-mlogloss:0.100633
# [81]	train-mlogloss:0.100429
# [82]	train-mlogloss:0.100239
# [83]	train-mlogloss:0.100044
# [84]	train-mlogloss:0.099851
# [85]	train-mlogloss:0.099668
# [86]	train-mlogloss:0.099487
# [87]	train-mlogloss:0.099315
# [88]	train-mlogloss:0.099156
# [89]	train-mlogloss:0.098998
# [90]	train-mlogloss:0.098843
# [91]	train-mlogloss:0.098697
# [92]	train-mlogloss:0.098545
# [93]	train-mlogloss:0.098404
# [94]	train-mlogloss:0.098263
# [95]	train-mlogloss:0.098137
# [96]	train-mlogloss:0.098022
# [97]	train-mlogloss:0.097971
# [98]	train-mlogloss:0.097920
# [99]	train-mlogloss:0.097870
# [100]	train-mlogloss:0.097821
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 26, number of used features: 0
# [LightGBM] [Info] Start training from score 2.730769
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 26, number of used features: 0
# [LightGBM] [Info] Start training from score -34.538776
# [LightGBM] [Info] Start training from score -1.871802
# [LightGBM] [Info] Start training from score -2.564949
# [LightGBM] [Info] Start training from score -0.424883
# [LightGBM] [Info] Start training from score -2.159484
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements

# %%
models_arima=train_models(train_data,train_label_arima)
arimaxgbreg=models_arima$xgbreg
arimaxgbcls=models_arima$xgbcls
arimalgbreg=models_arima$lgbreg
arimalgbcls=models_arima$lgbcls
# Out:
# [1]	train-rmse:1.506778
# [2]	train-rmse:1.119509
# [3]	train-rmse:0.833677
# [4]	train-rmse:0.634415
# [5]	train-rmse:0.490941
# [6]	train-rmse:0.378859
# [7]	train-rmse:0.295900
# [8]	train-rmse:0.231185
# [9]	train-rmse:0.181735
# [10]	train-rmse:0.143535
# [11]	train-rmse:0.114179
# [12]	train-rmse:0.091101
# [13]	train-rmse:0.073184
# [14]	train-rmse:0.059072
# [15]	train-rmse:0.047856
# [16]	train-rmse:0.038892
# [17]	train-rmse:0.031699
# [18]	train-rmse:0.025912
# [19]	train-rmse:0.020163
# [20]	train-rmse:0.015755
# [21]	train-rmse:0.012342
# [22]	train-rmse:0.009698
# [23]	train-rmse:0.007644
# [24]	train-rmse:0.006039
# [25]	train-rmse:0.004809
# [26]	train-rmse:0.003851
# [27]	train-rmse:0.003113
# [28]	train-rmse:0.002587
# [29]	train-rmse:0.002124
# [30]	train-rmse:0.001800
# [31]	train-rmse:0.001534
# [32]	train-rmse:0.001327
# [33]	train-rmse:0.001118
# [34]	train-rmse:0.000969
# [35]	train-rmse:0.000859
# [36]	train-rmse:0.000748
# [37]	train-rmse:0.000655
# [38]	train-rmse:0.000582
# [39]	train-rmse:0.000520
# [40]	train-rmse:0.000515
# [41]	train-rmse:0.000512
# [42]	train-rmse:0.000510
# [43]	train-rmse:0.000510
# [44]	train-rmse:0.000509
# [45]	train-rmse:0.000509
# [46]	train-rmse:0.000509
# [47]	train-rmse:0.000509
# [48]	train-rmse:0.000509
# [49]	train-rmse:0.000509
# [50]	train-rmse:0.000509
# [51]	train-rmse:0.000509
# [52]	train-rmse:0.000509
# [53]	train-rmse:0.000509
# [54]	train-rmse:0.000509
# [55]	train-rmse:0.000509
# [56]	train-rmse:0.000509
# [57]	train-rmse:0.000509
# [58]	train-rmse:0.000509
# [59]	train-rmse:0.000509
# [60]	train-rmse:0.000509
# [61]	train-rmse:0.000509
# [62]	train-rmse:0.000509
# [63]	train-rmse:0.000509
# [64]	train-rmse:0.000509
# [65]	train-rmse:0.000509
# [66]	train-rmse:0.000509
# [67]	train-rmse:0.000509
# [68]	train-rmse:0.000509
# [69]	train-rmse:0.000509
# [70]	train-rmse:0.000509
# [71]	train-rmse:0.000509
# [72]	train-rmse:0.000509
# [73]	train-rmse:0.000509
# [74]	train-rmse:0.000509
# [75]	train-rmse:0.000509
# [76]	train-rmse:0.000509
# [77]	train-rmse:0.000509
# [78]	train-rmse:0.000509
# [79]	train-rmse:0.000509
# [80]	train-rmse:0.000509
# [81]	train-rmse:0.000509
# [82]	train-rmse:0.000509
# [83]	train-rmse:0.000509
# [84]	train-rmse:0.000509
# [85]	train-rmse:0.000509
# [86]	train-rmse:0.000509
# [87]	train-rmse:0.000509
# [88]	train-rmse:0.000509
# [89]	train-rmse:0.000509
# [90]	train-rmse:0.000509
# [91]	train-rmse:0.000509
# [92]	train-rmse:0.000509
# [93]	train-rmse:0.000509
# [94]	train-rmse:0.000509
# [95]	train-rmse:0.000509
# [96]	train-rmse:0.000509
# [97]	train-rmse:0.000509
# [98]	train-rmse:0.000509
# [99]	train-rmse:0.000509
# [100]	train-rmse:0.000509
# [1]	train-mlogloss:1.266841
# [2]	train-mlogloss:1.024110
# [3]	train-mlogloss:0.836467
# [4]	train-mlogloss:0.680912
# [5]	train-mlogloss:0.562690
# [6]	train-mlogloss:0.481654
# [7]	train-mlogloss:0.417188
# [8]	train-mlogloss:0.361040
# [9]	train-mlogloss:0.317405
# [10]	train-mlogloss:0.280721
# [11]	train-mlogloss:0.251883
# [12]	train-mlogloss:0.230127
# [13]	train-mlogloss:0.208829
# [14]	train-mlogloss:0.193142
# [15]	train-mlogloss:0.181182
# [16]	train-mlogloss:0.172248
# [17]	train-mlogloss:0.164298
# [18]	train-mlogloss:0.158592
# [19]	train-mlogloss:0.153607
# [20]	train-mlogloss:0.149550
# [21]	train-mlogloss:0.145889
# [22]	train-mlogloss:0.142663
# [23]	train-mlogloss:0.139626
# [24]	train-mlogloss:0.136994
# [25]	train-mlogloss:0.134840
# [26]	train-mlogloss:0.132942
# [27]	train-mlogloss:0.131115
# [28]	train-mlogloss:0.129383
# [29]	train-mlogloss:0.127766
# [30]	train-mlogloss:0.126141
# [31]	train-mlogloss:0.124760
# [32]	train-mlogloss:0.123508
# [33]	train-mlogloss:0.122301
# [34]	train-mlogloss:0.121223
# [35]	train-mlogloss:0.120233
# [36]	train-mlogloss:0.119443
# [37]	train-mlogloss:0.118668
# [38]	train-mlogloss:0.117970
# [39]	train-mlogloss:0.117280
# [40]	train-mlogloss:0.116636
# [41]	train-mlogloss:0.116011
# [42]	train-mlogloss:0.115387
# [43]	train-mlogloss:0.114804
# [44]	train-mlogloss:0.114229
# [45]	train-mlogloss:0.113722
# [46]	train-mlogloss:0.113206
# [47]	train-mlogloss:0.112752
# [48]	train-mlogloss:0.112321
# [49]	train-mlogloss:0.111908
# [50]	train-mlogloss:0.111509
# [51]	train-mlogloss:0.111134
# [52]	train-mlogloss:0.110759
# [53]	train-mlogloss:0.110412
# [54]	train-mlogloss:0.110049
# [55]	train-mlogloss:0.109739
# [56]	train-mlogloss:0.109591
# [57]	train-mlogloss:0.109443
# [58]	train-mlogloss:0.109310
# [59]	train-mlogloss:0.109175
# [60]	train-mlogloss:0.109041
# [61]	train-mlogloss:0.108914
# [62]	train-mlogloss:0.108793
# [63]	train-mlogloss:0.108671
# [64]	train-mlogloss:0.108550
# [65]	train-mlogloss:0.108439
# [66]	train-mlogloss:0.108328
# [67]	train-mlogloss:0.108233
# [68]	train-mlogloss:0.108131
# [69]	train-mlogloss:0.108040
# [70]	train-mlogloss:0.107944
# [71]	train-mlogloss:0.107857
# [72]	train-mlogloss:0.107766
# [73]	train-mlogloss:0.107684
# [74]	train-mlogloss:0.107600
# [75]	train-mlogloss:0.107518
# [76]	train-mlogloss:0.107448
# [77]	train-mlogloss:0.107384
# [78]	train-mlogloss:0.107316
# [79]	train-mlogloss:0.107255
# [80]	train-mlogloss:0.107190
# [81]	train-mlogloss:0.107131
# [82]	train-mlogloss:0.107069
# [83]	train-mlogloss:0.107013
# [84]	train-mlogloss:0.106954
# [85]	train-mlogloss:0.106899
# [86]	train-mlogloss:0.106842
# [87]	train-mlogloss:0.106790
# [88]	train-mlogloss:0.106735
# [89]	train-mlogloss:0.106685
# [90]	train-mlogloss:0.106632
# [91]	train-mlogloss:0.106584
# [92]	train-mlogloss:0.106542
# [93]	train-mlogloss:0.106522
# [94]	train-mlogloss:0.106506
# [95]	train-mlogloss:0.106491
# [96]	train-mlogloss:0.106448
# [97]	train-mlogloss:0.106435
# [98]	train-mlogloss:0.106425
# [99]	train-mlogloss:0.106399
# [100]	train-mlogloss:0.106376
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 26, number of used features: 0
# [LightGBM] [Info] Start training from score 2.153846
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 26, number of used features: 0
# [LightGBM] [Info] Start training from score -2.159484
# [LightGBM] [Info] Start training from score -1.466337
# [LightGBM] [Info] Start training from score -2.159484
# [LightGBM] [Info] Start training from score -0.773190
# [LightGBM] [Info] Start training from score -2.564949
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements

# %%
models_nnetar=train_models(train_data,train_label_nnetar)
nnetarxgbreg=models_nnetar$xgbreg
nnetarxgbcls=models_nnetar$xgbcls
nnetarlgbreg=models_nnetar$lgbreg
nnetarlgbcls=models_nnetar$lgbcls
# Out:
# [1]	train-rmse:1.530349
# [2]	train-rmse:1.169962
# [3]	train-rmse:0.893554
# [4]	train-rmse:0.690083
# [5]	train-rmse:0.539220
# [6]	train-rmse:0.427249
# [7]	train-rmse:0.329252
# [8]	train-rmse:0.255162
# [9]	train-rmse:0.198855
# [10]	train-rmse:0.156367
# [11]	train-rmse:0.124100
# [12]	train-rmse:0.099254
# [13]	train-rmse:0.079778
# [14]	train-rmse:0.063901
# [15]	train-rmse:0.051862
# [16]	train-rmse:0.042119
# [17]	train-rmse:0.034336
# [18]	train-rmse:0.027556
# [19]	train-rmse:0.022275
# [20]	train-rmse:0.018132
# [21]	train-rmse:0.014729
# [22]	train-rmse:0.012048
# [23]	train-rmse:0.009843
# [24]	train-rmse:0.008010
# [25]	train-rmse:0.006526
# [26]	train-rmse:0.005337
# [27]	train-rmse:0.004361
# [28]	train-rmse:0.003581
# [29]	train-rmse:0.002939
# [30]	train-rmse:0.002423
# [31]	train-rmse:0.001978
# [32]	train-rmse:0.001655
# [33]	train-rmse:0.001379
# [34]	train-rmse:0.001149
# [35]	train-rmse:0.000976
# [36]	train-rmse:0.000837
# [37]	train-rmse:0.000719
# [38]	train-rmse:0.000631
# [39]	train-rmse:0.000551
# [40]	train-rmse:0.000544
# [41]	train-rmse:0.000541
# [42]	train-rmse:0.000539
# [43]	train-rmse:0.000539
# [44]	train-rmse:0.000538
# [45]	train-rmse:0.000538
# [46]	train-rmse:0.000538
# [47]	train-rmse:0.000538
# [48]	train-rmse:0.000538
# [49]	train-rmse:0.000538
# [50]	train-rmse:0.000538
# [51]	train-rmse:0.000538
# [52]	train-rmse:0.000538
# [53]	train-rmse:0.000538
# [54]	train-rmse:0.000538
# [55]	train-rmse:0.000538
# [56]	train-rmse:0.000538
# [57]	train-rmse:0.000538
# [58]	train-rmse:0.000538
# [59]	train-rmse:0.000538
# [60]	train-rmse:0.000538
# [61]	train-rmse:0.000538
# [62]	train-rmse:0.000538
# [63]	train-rmse:0.000538
# [64]	train-rmse:0.000538
# [65]	train-rmse:0.000538
# [66]	train-rmse:0.000538
# [67]	train-rmse:0.000538
# [68]	train-rmse:0.000538
# [69]	train-rmse:0.000538
# [70]	train-rmse:0.000538
# [71]	train-rmse:0.000538
# [72]	train-rmse:0.000538
# [73]	train-rmse:0.000538
# [74]	train-rmse:0.000538
# [75]	train-rmse:0.000538
# [76]	train-rmse:0.000538
# [77]	train-rmse:0.000538
# [78]	train-rmse:0.000538
# [79]	train-rmse:0.000538
# [80]	train-rmse:0.000538
# [81]	train-rmse:0.000538
# [82]	train-rmse:0.000538
# [83]	train-rmse:0.000538
# [84]	train-rmse:0.000538
# [85]	train-rmse:0.000538
# [86]	train-rmse:0.000538
# [87]	train-rmse:0.000538
# [88]	train-rmse:0.000538
# [89]	train-rmse:0.000538
# [90]	train-rmse:0.000538
# [91]	train-rmse:0.000538
# [92]	train-rmse:0.000538
# [93]	train-rmse:0.000538
# [94]	train-rmse:0.000538
# [95]	train-rmse:0.000538
# [96]	train-rmse:0.000538
# [97]	train-rmse:0.000538
# [98]	train-rmse:0.000538
# [99]	train-rmse:0.000538
# [100]	train-rmse:0.000538
# [1]	train-mlogloss:1.323466
# [2]	train-mlogloss:1.068422
# [3]	train-mlogloss:0.880751
# [4]	train-mlogloss:0.741434
# [5]	train-mlogloss:0.628281
# [6]	train-mlogloss:0.537817
# [7]	train-mlogloss:0.467789
# [8]	train-mlogloss:0.409778
# [9]	train-mlogloss:0.361427
# [10]	train-mlogloss:0.322793
# [11]	train-mlogloss:0.291058
# [12]	train-mlogloss:0.264044
# [13]	train-mlogloss:0.242413
# [14]	train-mlogloss:0.224889
# [15]	train-mlogloss:0.210577
# [16]	train-mlogloss:0.196323
# [17]	train-mlogloss:0.187013
# [18]	train-mlogloss:0.179311
# [19]	train-mlogloss:0.172827
# [20]	train-mlogloss:0.166457
# [21]	train-mlogloss:0.162102
# [22]	train-mlogloss:0.157400
# [23]	train-mlogloss:0.152869
# [24]	train-mlogloss:0.149339
# [25]	train-mlogloss:0.146111
# [26]	train-mlogloss:0.144607
# [27]	train-mlogloss:0.142876
# [28]	train-mlogloss:0.141663
# [29]	train-mlogloss:0.140610
# [30]	train-mlogloss:0.139602
# [31]	train-mlogloss:0.138605
# [32]	train-mlogloss:0.137693
# [33]	train-mlogloss:0.136819
# [34]	train-mlogloss:0.135922
# [35]	train-mlogloss:0.135128
# [36]	train-mlogloss:0.134309
# [37]	train-mlogloss:0.133516
# [38]	train-mlogloss:0.132723
# [39]	train-mlogloss:0.131950
# [40]	train-mlogloss:0.131189
# [41]	train-mlogloss:0.130452
# [42]	train-mlogloss:0.129725
# [43]	train-mlogloss:0.129005
# [44]	train-mlogloss:0.128329
# [45]	train-mlogloss:0.127647
# [46]	train-mlogloss:0.126962
# [47]	train-mlogloss:0.126278
# [48]	train-mlogloss:0.125634
# [49]	train-mlogloss:0.124988
# [50]	train-mlogloss:0.124359
# [51]	train-mlogloss:0.123738
# [52]	train-mlogloss:0.123118
# [53]	train-mlogloss:0.122533
# [54]	train-mlogloss:0.121941
# [55]	train-mlogloss:0.121327
# [56]	train-mlogloss:0.120771
# [57]	train-mlogloss:0.120178
# [58]	train-mlogloss:0.119595
# [59]	train-mlogloss:0.119059
# [60]	train-mlogloss:0.118518
# [61]	train-mlogloss:0.117982
# [62]	train-mlogloss:0.117454
# [63]	train-mlogloss:0.116917
# [64]	train-mlogloss:0.116416
# [65]	train-mlogloss:0.115924
# [66]	train-mlogloss:0.115387
# [67]	train-mlogloss:0.114912
# [68]	train-mlogloss:0.114449
# [69]	train-mlogloss:0.113942
# [70]	train-mlogloss:0.113472
# [71]	train-mlogloss:0.112996
# [72]	train-mlogloss:0.112541
# [73]	train-mlogloss:0.112095
# [74]	train-mlogloss:0.111642
# [75]	train-mlogloss:0.111227
# [76]	train-mlogloss:0.110786
# [77]	train-mlogloss:0.110370
# [78]	train-mlogloss:0.109943
# [79]	train-mlogloss:0.109547
# [80]	train-mlogloss:0.109156
# [81]	train-mlogloss:0.108767
# [82]	train-mlogloss:0.108382
# [83]	train-mlogloss:0.108019
# [84]	train-mlogloss:0.107658
# [85]	train-mlogloss:0.107283
# [86]	train-mlogloss:0.106941
# [87]	train-mlogloss:0.106601
# [88]	train-mlogloss:0.106266
# [89]	train-mlogloss:0.105931
# [90]	train-mlogloss:0.105622
# [91]	train-mlogloss:0.105303
# [92]	train-mlogloss:0.104985
# [93]	train-mlogloss:0.104691
# [94]	train-mlogloss:0.104405
# [95]	train-mlogloss:0.104130
# [96]	train-mlogloss:0.103859
# [97]	train-mlogloss:0.103598
# [98]	train-mlogloss:0.103349
# [99]	train-mlogloss:0.103108
# [100]	train-mlogloss:0.102875
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 26, number of used features: 0
# [LightGBM] [Info] Start training from score 1.884615
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 26, number of used features: 0
# [LightGBM] [Info] Start training from score -1.312186
# [LightGBM] [Info] Start training from score -1.871802
# [LightGBM] [Info] Start training from score -1.871802
# [LightGBM] [Info] Start training from score -1.312186
# [LightGBM] [Info] Start training from score -1.871802
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements

# %% [markdown]
# ## 预测与输出误差

# %%
alldatalgb <- lgb.Dataset(data = as.matrix(data_features))
alldataxgb <- xgb.DMatrix(data = as.matrix(data_features))

# %%
lgbcls_change<-function(lgbcls,ll)
    {
    lgbclsm=matrix(lgbcls,5,ll)
    lgbclsr=matrix(0,ll,1)
    for(i in 1:ll)
        {
        lgbclsr[i,]=which.max(lgbclsm[,i])

    }
    return(lgbclsr)
    }

# %%
xgbregets=predict(etsxgbreg,alldataxgb)
xgbclsets=predict(etsxgbcls,alldataxgb)
lgbregets=predict(etslgbreg,as.matrix(data_features))
lgbclsets=predict(etslgbcls,as.matrix(data_features))

# %%
xgbregthetaf=predict(thetafxgbreg,alldataxgb)
xgbclsthetaf=predict(thetafxgbcls,alldataxgb)
lgbregthetaf=predict(thetaflgbreg,as.matrix(data_features))
lgbclsthetaf=predict(thetaflgbcls,as.matrix(data_features))

# %%
xgbregarima=predict(arimaxgbreg,alldataxgb)
xgbclsarima=predict(arimaxgbcls,alldataxgb)
lgbregarima=predict(arimalgbreg,as.matrix(data_features))
lgbclsarima=predict(arimalgbcls,as.matrix(data_features))

# %%
xgbregnnetar=predict(nnetarxgbreg,alldataxgb)
xgbclsnnetar=predict(nnetarxgbcls,alldataxgb)
lgbregnnetar=predict(nnetarlgbreg,as.matrix(data_features))
lgbclsnnetar=predict(nnetarlgbcls,as.matrix(data_features))

# %%
lgbclsetsr=lgbcls_change(lgbclsets,ll)
lgbclsthetafr=lgbcls_change(lgbclsthetaf,ll)
lgbclsarimar=lgbcls_change(lgbclsarima,ll)
lgbclsnnetarr=lgbcls_change(lgbclsnnetar,ll)

# %%
round5=function(x)
    {
    l=round(x)
    for(i in 1:length(l))
    {
    if(l[i]>5)
        {
        l[i]=5
    }
    if(l[i]<1)
    {
        l[i]=1
    }
}
    l
}

# %%
ets_pr=matrix(0,ll,4)
ets_pr[,1]=round5(xgbregets+1)
ets_pr[,2]=xgbclsets+1
ets_pr[,3]=round5(lgbregets+1)
ets_pr[,4]=lgbclsetsr

# %%
thetaf_pr=matrix(0,ll,4)
thetaf_pr[,1]=round5(xgbregthetaf+1)
thetaf_pr[,2]=xgbclsthetaf+1
thetaf_pr[,3]=round5(lgbregthetaf+1)
thetaf_pr[,4]=lgbclsthetafr

# %%
arima_pr=matrix(0,ll,4)
arima_pr[,1]=round5(xgbregarima+1)
arima_pr[,2]=xgbclsarima+1
arima_pr[,3]=round5(lgbregarima+1)
arima_pr[,4]=lgbclsarimar

# %%
nnetar_pr=matrix(0,ll,4)
nnetar_pr[,1]=round5(xgbregnnetar+1)
nnetar_pr[,2]=xgbclsthetaf+1
nnetar_pr[,3]=round5(lgbregnnetar+1)
nnetar_pr[,4]=lgbclsnnetarr

# %%
meanpre=function(pred_array,opt_pr,h,testindex)
    {
    data_length=length(testindex)
    meanpreh=matrix(0,data_length,h)
    for (i in 1:data_length){
    index=testindex[i]
    loc=opt_pr[index]
    predh=pred_array[index,loc,,]
    predh=unique(predh)
    meanpreh[i,]=apply(predh,2,mean)
}
    return(meanpreh)
}

# %%
predres=function(pred_matrix,data,real_data,opt_pr,lengthmatrix,h,testindex)
    {
    data_length=length(testindex)
    pred_res=matrix(0,data_length,6)
    model=ets(data[[1]])
    fore_l=forecast(model,h=h)
    freq=frequency(data[[1]])
    for (i in 1:data_length){
    index=testindex[i]
    loc=opt_pr[index]
    start=lengthmatrix[i,loc]
    y_all=data[[index]]
    y=y_all[start:length(y_all)]
    fore_l$x=ts(y,frequency=freq,end=end(y_all))
    real=real_data[[index]]
    fore_l$mean=ts(pred_matrix[i,],start=start(real),frequency=freq)
    res=accuracy(fore_l,real)
    pred_res[i,]=res[2,1:6]
    }
    return(pred_res)
    }

# %%
testindex=c(1:ll)[index==2]
lengthtest=length5[testindex,]
etsxgbcls=meanpre(predhets,ets_pr[,1],hh,testindex)
etsxgbreg=meanpre(predhets,ets_pr[,2],hh,testindex)
etslgbcls=meanpre(predhets,ets_pr[,3],hh,testindex)
etslgbreg=meanpre(predhets,ets_pr[,4],hh,testindex)
etsxgbclsres=predres(etsxgbcls,data_tstrain,y_real,ets_pr[,1],lengthtest,hh,testindex)
etsxgbregres=predres(etsxgbreg,data_tstrain,y_real,ets_pr[,2],lengthtest,hh,testindex)
etslgbclsres=predres(etslgbcls,data_tstrain,y_real,ets_pr[,3],lengthtest,hh,testindex)
etslgbregres=predres(etslgbreg,data_tstrain,y_real,ets_pr[,4],lengthtest,hh,testindex)

# %%
thetafxgbcls=meanpre(predhthetaf,thetaf_pr[,1],hh,testindex)
thetafxgbreg=meanpre(predhthetaf,thetaf_pr[,2],hh,testindex)
thetaflgbcls=meanpre(predhthetaf,thetaf_pr[,3],hh,testindex)
thetaflgbreg=meanpre(predhthetaf,thetaf_pr[,4],hh,testindex)
thetafxgbclsres=predres(thetafxgbcls,data_tstrain,y_real,thetaf_pr[,1],lengthtest,hh,testindex)
thetafxgbregres=predres(thetafxgbreg,data_tstrain,y_real,thetaf_pr[,2],lengthtest,hh,testindex)
thetaflgbclsres=predres(thetaflgbcls,data_tstrain,y_real,thetaf_pr[,3],lengthtest,hh,testindex)
thetaflgbregres=predres(thetaflgbreg,data_tstrain,y_real,thetaf_pr[,4],lengthtest,hh,testindex)

# %%
arimaxgbcls=meanpre(predharima,arima_pr[,1],hh,testindex)
arimaxgbreg=meanpre(predharima,arima_pr[,2],hh,testindex)
arimalgbcls=meanpre(predharima,arima_pr[,3],hh,testindex)
arimalgbreg=meanpre(predharima,arima_pr[,4],hh,testindex)
arimaxgbclsres=predres(arimaxgbcls,data_tstrain,y_real,ets_pr[,1],lengthtest,hh,testindex)
arimaxgbregres=predres(arimaxgbreg,data_tstrain,y_real,ets_pr[,2],lengthtest,hh,testindex)
arimalgbclsres=predres(arimalgbcls,data_tstrain,y_real,ets_pr[,3],lengthtest,hh,testindex)
arimalgbregres=predres(arimalgbreg,data_tstrain,y_real,ets_pr[,4],lengthtest,hh,testindex)

# %%
nnetarxgbcls=meanpre(predhnnetar,nnetar_pr[,1],hh,testindex)
nnetarxgbreg=meanpre(predhnnetar,nnetar_pr[,2],hh,testindex)
nnetarlgbcls=meanpre(predhnnetar,nnetar_pr[,3],hh,testindex)
nnetarlgbreg=meanpre(predhnnetar,nnetar_pr[,4],hh,testindex)
nnetarxgbclsres=predres(nnetarxgbcls,data_tstrain,y_real,nnetar_pr[,1],lengthtest,hh,testindex)
nnetarxgbregres=predres(nnetarxgbreg,data_tstrain,y_real,nnetar_pr[,2],lengthtest,hh,testindex)
nnetarlgbclsres=predres(nnetarlgbcls,data_tstrain,y_real,nnetar_pr[,3],lengthtest,hh,testindex)
nnetarlgbregres=predres(nnetarlgbreg,data_tstrain,y_real,nnetar_pr[,4],lengthtest,hh,testindex)

# %%
apply(predets[,1,1,],2,mean)
apply(etsxgbclsres,2,mean)
apply(etsxgbregres,2,mean)
apply(etslgbclsres,2,mean)
apply(etslgbregres,2,mean)
# Out:
# [1] -138.902612  255.854471  194.002391   -8.209122   11.214019    1.424924
# [1]  41.1221329 104.0387974  88.4378065   4.1426083   7.2012236   0.8284007
# [1] 19.3964359 91.3712746 74.2132876  1.1409548  4.8581478  0.4498241
# [1] 20.1908214 81.3631135 65.9287494  1.5521963  4.7060372  0.4058962
# [1] -28.4543311 101.1704789  81.9677523  -1.9393219   6.2396525   0.7774386

# %%
apply(predthetaf[,1,1,],2,mean)
apply(thetafxgbclsres,2,mean)
apply(thetafxgbregres,2,mean)
apply(thetaflgbclsres,2,mean)
apply(thetaflgbregres,2,mean)
# Out:
# [1]   5.238668 276.405939 227.056177  -2.557975  14.889043   1.702292
# [1]  95.9244149 139.3830395 115.4055789   7.3173015   8.4012706   0.9707171
# [1]  94.023232 141.046753 118.068624   7.234225   8.544567   1.004956
# [1]  91.1499577 134.4057105 111.1360585   6.9087439   8.0167080   0.9185397
# [1]  28.381882 184.448281 144.817285   2.548887  10.202365   1.131705

# %%
apply(predarima[,1,1,],2,mean)
apply(arimaxgbclsres,2,mean)
apply(arimaxgbregres,2,mean)
apply(arimalgbclsres,2,mean)
apply(arimalgbregres,2,mean)
# Out:
# [1] -94.656598 205.686059 156.604550  -8.753980  11.484376   1.187568
# [1] -50.9811662 112.4089601  93.6991388  -5.6215763   8.1266384   0.5541547
# [1] -57.9943350 116.6303425  95.8714661  -6.1588085   8.3967089   0.5560411
# [1] -21.4427931  93.6234178  69.8370816  -2.5042711   5.1046876   0.4598434
# [1] -64.0142489 104.1598226  86.7362235  -7.1155707   8.3056726   0.5731619

# %%
apply(prednnetar[,1,1,],2,mean)
apply(nnetarxgbclsres,2,mean)
apply(nnetarxgbregres,2,mean)
apply(nnetarlgbclsres,2,mean)
apply(nnetarlgbregres,2,mean)
# Out:
# [1] -25.986401 246.420930 184.468462  -4.729483  13.262368   1.532026
# [1]  51.877117 167.115929 136.210747   4.440948  10.973591   1.135362
# [1]   7.3055512 155.8615948 135.7976029   1.5077545   8.0088358   0.9142693
# [1]  77.0038392 141.9735765 122.1308862   6.5176755   9.8832102   0.9878804
# [1]  12.593518 161.836211 120.652829   1.482972  10.000789   1.204414

# %%
alltest=matrix(0,20,6)
alltest[1,]=apply(predets[,1,1,],2,mean)
alltest[2,]=apply(etsxgbclsres,2,mean)
alltest[3,]=apply(etsxgbregres,2,mean)
alltest[4,]=apply(etslgbclsres,2,mean)
alltest[5,]=apply(etslgbregres,2,mean)

alltest[6,]=apply(predthetaf[,1,1,],2,mean)
alltest[7,]=apply(thetafxgbclsres,2,mean)
alltest[8,]=apply(thetafxgbregres,2,mean)
alltest[9,]=apply(thetaflgbclsres,2,mean)
alltest[10,]=apply(thetaflgbregres,2,mean)

alltest[11,]=apply(predarima[,1,1,],2,mean)
alltest[12,]=apply(arimaxgbclsres,2,mean)
alltest[13,]=apply(arimaxgbregres,2,mean)
alltest[14,]=apply(arimalgbclsres,2,mean)
alltest[15,]=apply(arimalgbregres,2,mean)

alltest[16,]=apply(prednnetar[,1,1,],2,mean)
alltest[17,]=apply(nnetarxgbclsres,2,mean)
alltest[18,]=apply(nnetarxgbregres,2,mean)
alltest[19,]=apply(nnetarlgbclsres,2,mean)
alltest[20,]=apply(nnetarlgbregres,2,mean)

# %%
write.csv(alltest,'industry_by_oneself.csv')
